# %% [markdown]
# # 総合演習をする

# %%
class Uchika():    
    def menu(self) -> int:
        functions = ["乗車駅選択", "チャージ機能"]
        print("【ウチダ電鉄　交通系ICカード検証システム】\n")
        for i in range(len(functions)):
            print(f"{i+1}: {functions[i]}")
        
        print("使用する機能を選択してください（終了する場合には99を入力）\n")
        input_func = int(input("機能選択"))
        # if input_func == 99:
        #     return 0
        return input_func
    
    def select_station(self) -> int:   # 辞書にしたほうが良くね？
        stations = ["秋葉原", "山梨", "長野"]
        fares = [133, 4128, 7990]
        print("【乗車駅選択】\n")
        for i in range(len(stations)):
            print(f"{i+1}: {stations[i]}駅から : {fares[i]}円")
        print("\n乗車した駅を入力してください（キャンセルする場合には99を入力）\n")
        
        destination = int(input("乗車駅入力"))
        if destination == 99:
            print("駅の選択をキャンセルしました．")
            return 0
        print(f"乗車駅は{stations[destination-1]}で料金は{fares[destination-1]}円です．")
        return destination - 1
    
    def pay(self, balance: int, fare: int) -> int:  # charge=残高
        charge = 3000
        print(f"チャージ残高は{balance}円です．")
        if balance < fare:
            print("残高不足です．")
            while balance < fare:
                print(f"{charge}円自動チャージします．")
                balance += charge
        balance -= fare  # 精算
        
        if balance < 500:
            print(f"残高が500円未満のため{charge}円自動チャージします．")
            balance += charge
            print(f"チャージ残高は{balance}円です．")
        return balance
    
    def charge(self, balance: int) -> int:
        charges = []
        for i in range(1000, 11000, 1000):
            charges.append(i)
        # print(charge)
        print("【チャージ機能】\n")
        print(f"チャージ残高は{balance}円です．\n")
        for i in range(len(charges)):
            print(f"{i+1}: {charges}円\n")
        print("チャージする金額を選択してください（キャンセルする場合には99を入力）")
        
        input_charge = int(input())
        if input_charge > 1 and input_charge < 11:
            print(f"{input_charge * 1000}円チャージします．")
            balance += input_charge
        elif input_charge == 99:
            print("チャージをキャンセルしました．")
        print(f"チャージ残高は{balance}円です．")
        return balance
    
def main():
    uchika = Uchika()
    balance = 500   # 残高を初期化
    while True:
        menu = uchika.menu()
        if menu == 1:
            fare = uchika.select_station()
            if fare != 0:
                balance = uchika.pay(balance, fare)
        elif menu == 2:
            balance = uchika.charge()
        elif menu == 99:
            print("システムを終了します．")
            break
                
if __name__ == "__main__":
    main()
# Out:
# 【ウチダ電鉄　交通系ICカード検証システム】
#
# 1: 乗車駅選択
# 2: チャージ機能
# 使用する機能を選択してください（終了する場合には99を入力）
#
# 【乗車駅選択】
#
# 1: 秋葉原駅から : 133円
# 2: 山梨駅から : 4128円
# 3: 長野駅から : 7990円
#
# 乗車した駅を入力してください（キャンセルする場合には99を入力）
#
# 乗車駅は秋葉原で料金は133円です．
# 【ウチダ電鉄　交通系ICカード検証システム】
#
# 1: 乗車駅選択
# 2: チャージ機能
# 使用する機能を選択してください（終了する場合には99を入力）
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 81
#      78             break
#      80 if __name__ == "__main__":
# ---> 81     main()
#
# Cell In[7], line 69, in main()
#      67 balance = 500   # 残高を初期化
#      68 while True:
# ---> 69     menu = uchika.menu()
#      70     if menu == 1:
#      71         fare = uchika.select_station()
#
# Cell In[7], line 9, in Uchika.menu(self)
#       6     print(f"{i+1}: {functions[i]}")
#       8 print("使用する機能を選択してください（終了する場合には99を入力）\n")
# ----> 9 input_func = int(input("機能選択"))
#      10 # if input_func == 99:
#      11 #     return 0
#      12 return input_func
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def charge(aaa) -> int:
    charge = []
    for i in range(1000, 11000, 1000):
        charge[i] = i
    print(charge)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 6
#       4         charge[i] = i
#       5     print(charge)
# ----> 6 charge(1000)
#
# Cell In[15], line 4, in charge(aaa)
#       2 charge = []
#       3 for i in range(1000, 11000, 1000):
# ----> 4     charge[i] = i
#       5 print(charge)
#
# IndexError: list assignment index out of range
